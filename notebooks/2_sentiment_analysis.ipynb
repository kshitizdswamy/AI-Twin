# %% [markdown]
# # Notebook 2: Sentiment Analysis & Emotion Detection 🧠
# This notebook demonstrates NLP processing using HuggingFace Transformers, fine-grained emotion detection, and text summarization.

# %%
import sys
import os
sys.path.append(os.path.abspath('..'))

from src.models.sentiment_model import SentimentEmotionAnalyzer

analyzer = SentimentEmotionAnalyzer(use_transformers=False)
sample_text = "Had an extraordinarily productive day building our AI Twin project! Feeling energized and proud."

res = analyzer.analyze_sentiment_and_emotion(sample_text)
summary = analyzer.summarize_text(sample_text)

print("Sentiment Analysis Output:", res)
print("Summary:", summary)
