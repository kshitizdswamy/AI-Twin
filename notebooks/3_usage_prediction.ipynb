# %% [markdown]
# # Notebook 3: Usage Prediction & Anomaly Detection 🔮
# This notebook covers model training using Random Forest / Gradient Boosting for screen time forecasting and Isolation Forest for anomaly detection.

# %%
import sys
import os
sys.path.append(os.path.abspath('..'))

from src.models.train import train_pipeline

metrics = train_pipeline()
print("Training Complete. Metrics:", metrics)
